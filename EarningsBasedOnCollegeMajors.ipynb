# %%
## Setting up the environment for plotting
## and including the datasets necessary.

import pandas as pd
import matplotlib as mlib

# %matplotlib inline

recent_grads = pd.read_csv("recent-grads.csv")

# %%
## Just to get the structure of data
recent_grads.iloc[1]
recent_grads.head()
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# 169      ...              572                  1211         148
# 170      ...              648                  1293         368
# 171      ...              965                  2738         214
# 172      ...              237                   410          87
#
#      Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 168           0.046320   26000  20000  39000          2771              2947
# 169           0.065112   25000  24000  34000          1488               615
# 170           0.149048   25000  25000  40000           986               870
# 171           0.053621   23400  19200  26000          2403              1245
# 172           0.104946   22000  20000  22000           288               338
#
#      Low_wage_jobs
# 168            743
# 169             82
# 170            622
# 171            308
# 172            192
#
# [5 rows x 21 columns]

# %%
## Summary Statistics
recent_grads.describe()
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000            NaN            NaN            NaN
# 50%     87.000000  3608.000000            NaN            NaN            NaN
# 75%    130.000000  5503.000000            NaN            NaN            NaN
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# std      0.231205   618.361022   50675.002241   42869.655092   14648.179473
# min      0.000000     2.000000       0.000000     111.000000       0.000000
# 25%           NaN    39.000000    3608.000000    3154.000000    1030.000000
# 50%           NaN   130.000000   11797.000000   10048.000000    3299.000000
# 75%           NaN   338.000000   31433.000000   25147.000000    9948.000000
# max      0.968954  4212.000000  307933.000000  251540.000000  115172.000000
#
#        Full_time_year_round    Unemployed  Unemployment_rate         Median  \
# count            173.000000    173.000000         173.000000     173.000000
# mean           19694.427746   2416.329480           0.068191   40151.445087
# std            33160.941514   4112.803148           0.030331   11470.181802
# min              111.000000      0.000000           0.000000   22000.000000
# 25%             2453.000000    304.000000           0.050306   33000.000000
# 50%             7413.000000    893.000000           0.067961   36000.000000
# 75%            16891.000000   2393.000000           0.087557   45000.000000
# max           199897.000000  28169.000000           0.177226  110000.000000
#
#               P25th          P75th   College_jobs  Non_college_jobs  \
# count    173.000000     173.000000     173.000000        173.000000
# mean   29501.445087   51494.219653   12322.635838      13284.497110
# std     9166.005235   14906.279740   21299.868863      23789.655363
# min    18500.000000   22000.000000       0.000000          0.000000
# 25%    24000.000000   42000.000000    1675.000000       1591.000000
# 50%    27000.000000   47000.000000    4390.000000       4595.000000
# 75%    33000.000000   60000.000000   14444.000000      11783.000000
# max    95000.000000  125000.000000  151643.000000     148395.000000
#
#        Low_wage_jobs
# count     173.000000
# mean     3859.017341
# std      6944.998579
# min         0.000000
# 25%       340.000000
# 50%      1231.000000
# 75%      3466.000000
# max     48207.000000

# %%
## Removing NULL values
raw_data_count = len(recent_grads.index)
recent_grads = recent_grads.dropna()
cleaned_data_count = len(recent_grads.index)
print(raw_data_count)
print(cleaned_data_count)
# Out:
# 173
# 172

# %%
## Some Scatter Plots of various relations
ax = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax.set_title('Sample_size vs. Median')

# %%
ax = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax.set_title('Sample_size vs. Unemployment_rate')

# %%
ax = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax.set_title('Full_time vs. Median')

# %%
ax = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax.set_title('ShareWomen vs. Unemployment_rate')

# %%
ax = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax.set_title('Men vs. Median')

# %%
ax = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax.set_title('Women vs. Median')

# %%
## Some histogram plots for various fields

recent_grads["Sample_size"].plot(kind='hist', rot=40)

# %%
recent_grads["Median"].plot(kind='hist', rot=40)

# %%
recent_grads["Employed"].plot(kind='hist', rot=40)

# %%
recent_grads["Full_time"].plot(kind='hist', rot=40)

# %%
recent_grads["ShareWomen"].plot(kind='hist', rot=40)

# %%
recent_grads["Unemployment_rate"].plot(kind='hist', rot=40)

# %%
recent_grads["Men"].plot(kind='hist', rot=40)

# %%
recent_grads["Women"].plot(kind='hist', rot=40)

# %%
## Employing Pandas Scatter Matrix Plot

from pandas.tools.plotting import scatter_matrix

scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f26e47de710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f26e47cb7f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f26e471a160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f26e474fdd8>]], dtype=object)

# %%
## Scatter Matrix of 3 variables wil create a 3*3 matrix

scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f26e467f518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f26e45ef780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f26e45bc198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f26e4573dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f26e453de48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f26e44fe748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f26e44ce438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f26e450b278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f26e43d2780>]], dtype=object)

# %%
## Bar Plots in Pandas
## Comparison of % of women from 10 highest and lowest paying Majors

recent_grads[:10].plot.bar(x='Major', y='Women', legend=False)
recent_grads[163:].plot.bar(x='Major', y='Women', legend=False)

# %%
## Comparison of Unemployment Rate from 10 highest and lowest paying majors

recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)
recent_grads[163:].plot.bar(x='Major', y='Unemployment_rate', legend=False)
